# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from tqdm import tqdm_notebook

import gensim
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

from sklearn import utils
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

import seaborn as sns

import multiprocessing

import re

import nltk
from nltk.corpus import stopwords

# %matplotlib inline

# %%
data_embeddings = pd.read_csv('df_embeddings.csv')
data_embeddings.head(2)
# Out:
#    Unnamed: 0                 course_id  \
# 0           0                2-speed-it
# 1           1  3d-printing-applications
#
#                              embeddings_course_descr
# 0  [0.062335819005966187, 0.015386137180030346, 0...
# 1  [-0.010602016001939774, -0.0638212189078331, 0...

# %%
data_embeddings=data_embeddings.drop(['Unnamed: 0'], axis=1)

# %%
vectors = []

for i, row in data_embeddings.iterrows():
    vect_str = row['embeddings_course_descr']
    vect = np.fromstring( vect_str.replace('[', '').replace(']', ''), dtype=np.float, sep=',' )
    vectors.append(vect)

df_vectors = pd.DataFrame(vectors)
df_vectors.head(2)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.062336  0.015386  0.001798  0.036211 -0.025498  0.004170 -0.063827
# 1 -0.010602 -0.063821  0.044484  0.059159  0.050023 -0.040048 -0.067637
#
#         7         8         9    ...       502       503       504       505  \
# 0 -0.014235 -0.047241  0.063943  ...  0.038421  0.010176  0.035355 -0.059017
# 1 -0.055488  0.055521 -0.004766  ... -0.044688 -0.051190  0.034932 -0.067331
#
#         506       507       508       509       510       511
# 0 -0.053254  0.012399  0.056702 -0.061181 -0.055130  0.020926
# 1 -0.013376  0.031566  0.050381 -0.057320 -0.004899  0.044088
#
# [2 rows x 512 columns]

# %%
data_embeddings = data_embeddings.join(df_vectors).drop(['embeddings_course_descr'], axis=1)
data_embeddings.head(2)
# Out:
#                   course_id         0         1         2         3         4  \
# 0                2-speed-it  0.062336  0.015386  0.001798  0.036211 -0.025498
# 1  3d-printing-applications -0.010602 -0.063821  0.044484  0.059159  0.050023
#
#           5         6         7         8  ...       502       503       504  \
# 0  0.004170 -0.063827 -0.014235 -0.047241  ...  0.038421  0.010176  0.035355
# 1 -0.040048 -0.067637 -0.055488  0.055521  ... -0.044688 -0.051190  0.034932
#
#         505       506       507       508       509       510       511
# 0 -0.059017 -0.053254  0.012399  0.056702 -0.061181 -0.055130  0.020926
# 1 -0.067331 -0.013376  0.031566  0.050381 -0.057320 -0.004899  0.044088
#
# [2 rows x 513 columns]

# %%
len(data_embeddings)
# Out:
# 1299

# %%
data_embeddings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Columns: 513 entries, course_id to 511
# dtypes: float64(512), object(1)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Рекомендации на основе содержания

# %%
# ITEM_TO_USER

# %%
#достанем информацию об оценках пользователей из data.csv
courses_eng_1 = pd.read_csv('courses_eng_1.csv')
courses_eng = courses_eng_1[['new_course_id','course_id']]
"""#избавимся от лишних столбцов
data_reviews=data_reviews.drop(['Unnamed: 0'], axis=1)
data_reviews=data_reviews.drop(['reviewer_name'], axis=1)
data_reviews=data_reviews.drop(['review_text'], axis=1)
"""
courses_eng.head(2)
# Out:
#    new_course_id                 course_id
# 0              0                2-speed-it
# 1              5  3d-printing-applications

# %%
len(courses_eng)
# Out:
# 1299

# %%
data_courses_embeddings = data_embeddings.join(courses_eng.set_index('course_id'), on='course_id')

# %%
#достанем информацию об оценках пользователей из data.csv
data_reviews = pd.read_csv('reviews_eng_courses_1.csv')
#избавимся от лишних столбцов
data_reviews=data_reviews.drop(['Unnamed: 0'], axis=1)
data_reviews=data_reviews.drop(['reviewer_name'], axis=1)
data_reviews=data_reviews.drop(['review_text'], axis=1)

data_reviews.head(2)
# Out:
#     course_id  rating  reviewer_id
# 0  2-speed-it       5        60888
# 1  2-speed-it       2        22416

# %%
len(data_reviews)
# Out:
# 157938

# %%
#объединим датафрейм описания англоязычных курсов с отзывами пользователей 
data_reviews_with_desc =  data_reviews.join(courses_eng.set_index('course_id'), on='course_id')
data_reviews_with_desc.head(3)
# Out:
#     course_id  rating  reviewer_id  new_course_id
# 0  2-speed-it       5        60888              0
# 1  2-speed-it       2        22416              0
# 2  2-speed-it       4        76208              0

# %%
#data_reviews.rating = data_reviews.rating.astype(int)

# %%
len(data_reviews_with_desc)
# Out:
# 157938

# %%
#объединим датафрейм описания англоязычных курсов с отзывами пользователей 
data_embed_rait =  data_reviews_with_desc.join(data_embeddings.set_index('course_id'), on='course_id')
data_embed_rait.head(2)
# Out:
#     course_id  rating  reviewer_id  new_course_id         0         1  \
# 0  2-speed-it       5        60888              0  0.062336  0.015386
# 1  2-speed-it       2        22416              0  0.062336  0.015386
#
#           2         3         4        5  ...       502       503       504  \
# 0  0.001798  0.036211 -0.025498  0.00417  ...  0.038421  0.010176  0.035355
# 1  0.001798  0.036211 -0.025498  0.00417  ...  0.038421  0.010176  0.035355
#
#         505       506       507       508       509      510       511
# 0 -0.059017 -0.053254  0.012399  0.056702 -0.061181 -0.05513  0.020926
# 1 -0.059017 -0.053254  0.012399  0.056702 -0.061181 -0.05513  0.020926
#
# [2 rows x 516 columns]

# %%
len(data_embed_rait)
# Out:
# 157938

# %%
#объединим с датафреймом по оценкам пользователей

# %%
#посмотрим сколько отзывов поставил каждый пользователь
data_embed_rait.groupby('reviewer_id')[['course_id']].count().sort_values('course_id', ascending=False)
# Out:
#              course_id
# reviewer_id
# -1                 825
#  31616             136
#  34943             125
#  36039             100
#  61783              66
#  51060              65
#  48932              60
#  16636              59
#  17412              58
#  19166              57
#  17378              56
#  48995              55
#  16775              55
#  17465              54
#  17329              54
#  48975              54
#  10210              50
#  17344              49
#  32263              46
#  35295              46
#  32650              45
#  32245              45
#  10723              45
#  16729              44
#  34654              44
#  17333              44
#  34735              44
#  5560               43
#  42628              42
#  50249              42
# ...                ...
#  40644               1
#  40645               1
#  40646               1
#  40647               1
#  40648               1
#  40650               1
#  40651               1
#  40652               1
#  40653               1
#  40654               1
#  40655               1
#  40656               1
#  40657               1
#  40658               1
#  40659               1
#  40660               1
#  40661               1
#  40662               1
#  40663               1
#  40664               1
#  40665               1
#  40666               1
#  40667               1
#  40668               1
#  40669               1
#  40670               1
#  40671               1
#  40672               1
#  40673               1
#  89698               1
#
# [88851 rows x 1 columns]

# %%
#удалённые имена пользователей = -1

# %%
data_embed_rait.groupby('course_id')[['rating']].count().sort_values('rating', ascending=False)
# Out:
#                                                     rating
# course_id
# matlab                                                 928
# project-management-basics                              917
# game-development                                       907
# data-cleaning                                          897
# algorithmic-toolbox                                    893
# data-science-course                                    866
# science-of-meditation                                  865
# mindshift                                              844
# learn-to-program                                       808
# language-theories                                      801
# uva-darden-design-thinking-innovation                  788
# philosophy                                             787
# website-coding                                         763
# ml-regression                                          763
# professional-emails-english                            760
# object-oriented-java                                   753
# positive-psychology-visionary-science                  742
# search-engine-optimization                             736
# careerdevelopment                                      731
# python-programming-introduction                        718
# introduction-psych                                     716
# wharton-quantitative-modeling                          714
# introcss                                               700
# gis                                                    677
# arduino-platform                                       668
# probability-intro                                      648
# introduction-to-software-product-management            647
# dog-emotion-and-cognition                              647
# positive-psychology                                    643
# interactive-python-1                                   627
# ...                                                    ...
# bd2k-lincs                                               4
# capital-budgeting                                        4
# literacy-teaching-learning                               4
# startup-entrepreneurship-innovation-career-lessons       4
# internet-of-things-capstone                              3
# quantitative-formal-modeling-1                           3
# analysis-business-problem-iese                           3
# metaliteracy                                             3
# soscapproachchina1                                       3
# be-a-leader                                              3
# linear-models-2                                          3
# english-for-business-project                             3
# datasci-capstone                                         3
# market-efficiency                                        3
# modular-forms-jacobi                                     3
# systems-biology-capstone                                 3
# aoo                                                      2
# developpement-urbain                                     2
# transreality-gaming                                      2
# creating-innovation                                      2
# interpersonal-communication                              2
# teaching-common-grammar-mistakes                         2
# iot-augmented-reality-technologies                       2
# integrated-analysis                                      2
# bioinformatics-project                                   2
# multimodal-literacies                                    2
# investment-strategy-capstone                             2
# career-planning                                          1
# power-onboarding                                         1
# e-learning                                               1
#
# [1298 rows x 1 columns]

# %%
#выберем очень активного пользователя с reviewer_id = 36039
TARGET_USER = 10210
#выбарем все оцененные этим пользователем курсы
df_for_user = data_embed_rait[data_embed_rait['reviewer_id']==TARGET_USER]
df_for_user
# Out:
#                                      course_id  rating  reviewer_id  \
# 3087                            ageofjefferson       5        10210
# 5387                                  altruism       5        10210
# 7190                            ancient-greeks       5        10210
# 7390                   ancient-marine-reptiles       4        10210
# 8885                               archoftitus       5        10210
# 11119                        audio-engineering       4        10210
# 14792                              big-history       5        10210
# 15318                 bioinformatics-methods-1       5        10210
# 15389                 bioinformatics-methods-1       5        10210
# 21813   client-needs-and-software-requirements       4        10210
# 41297                    dyslexia-difficulties       5        10210
# 41414               early-vertebrate-evolution       5        10210
# 42931                              electronics       5        10210
# 43111                       emergent-phenomena       5        10210
# 45049                             epidemiology       5        10210
# 46227           everyday-leadership-foundation       5        10210
# 49284                          family-planning       4        10210
# 53300                         forensic-science       5        10210
# 57090                        gamedev-platforms       5        10210
# 60046                            global-energy       5        10210
# 62299                   health-care-innovation       5        10210
# 65458                           human-language       5        10210
# 66709                        implant-dentistry       5        10210
# 79513                  journey-of-the-universe       5        10210
# 89016                        material-behavior       4        10210
# 96071                         modern-art-ideas       5        10210
# 98304                    motivate-people-teams       5        10210
# 98305                    motivate-people-teams       3        10210
# 98787                            mountains-101       4        10210
# 103879                 organizational-analysis       5        10210
# 106231                              philosophy       5        10210
# 106302                              philosophy       5        10210
# 113171                          private-equity       5        10210
# 124164                       regression-models       3        10210
# 126586                       robotics-learning       5        10210
# 126606                       robotics-mobility       1        10210
# 128432                    scala-spark-big-data       4        10210
# 128910                       schedule-projects       5        10210
# 133019  software-processes-and-agile-practices       5        10210
# 133484                              solar-cell       5        10210
# 133737                            solar-system       5        10210
# 133769                  solid-waste-management       4        10210
# 141485             teaching-english-capstone-2       5        10210
# 142592                        tesol-technology       5        10210
# 143024                          text-retrieval       3        10210
# 143090                          text-retrieval       5        10210
# 143954                            thomas-berry       5        10210
# 150071      uva-darden-smart-growth-strategy-1       5        10210
# 150218      uva-darden-smart-growth-strategy-2       5        10210
# 152109                          website-coding       4        10210
#
#         new_course_id         0         1         2         3         4  \
# 3087               42 -0.017314 -0.001662 -0.027840 -0.061607  0.042819
# 5387               62 -0.008544 -0.022144  0.048564  0.030201  0.011163
# 7190               79  0.029129  0.006605 -0.054073 -0.061880  0.057992
# 7390               80 -0.027196  0.062703  0.018533 -0.031129  0.020533
# 8885              104  0.007273  0.048132  0.034198 -0.044644  0.054894
# 11119             124  0.030083  0.029936  0.016344  0.029272 -0.012876
# 14792             162  0.035675  0.050006 -0.036288 -0.041000  0.066920
# 15318             170 -0.040018  0.051751 -0.052735  0.059960  0.028560
# 15389             170 -0.040018  0.051751 -0.052735  0.059960  0.028560
# 21813             270  0.010585 -0.033856 -0.017261  0.058840 -0.070238
# 41297             479  0.019582 -0.047357 -0.007944  0.078534  0.055413
# 41414             481 -0.015435  0.026983 -0.021780  0.044318  0.005881
# 42931             512 -0.004366 -0.007844  0.007871  0.015230  0.036596
# 43111             520 -0.045465  0.006173 -0.054643 -0.032328  0.067917
# 45049             552 -0.022204 -0.035900  0.027416  0.069804  0.060661
# 46227             582  0.063796 -0.018691 -0.016476 -0.023426  0.050766
# 49284             596 -0.064282 -0.014884  0.047591  0.046721  0.042486
# 53300             641 -0.062531  0.053608 -0.034125  0.061215  0.064335
# 57090             673  0.067491  0.023109 -0.030929 -0.010154 -0.002486
# 60046             721  0.054615 -0.055962  0.056560 -0.059532  0.057471
# 62299             751  0.051021 -0.057186  0.026822  0.064549  0.057804
# 65458             799 -0.054637  0.060314 -0.023996  0.055392  0.040795
# 66709             816  0.028035  0.022869  0.055060  0.057481  0.039795
# 79513             959  0.010348  0.054857  0.040544 -0.022212  0.061133
# 89016            1072  0.010314 -0.010305 -0.061875  0.014156  0.063423
# 96071            1125 -0.059310 -0.043076  0.044007  0.056553  0.059471
# 98304            1144  0.065789 -0.008934 -0.044258 -0.012927  0.052110
# 98305            1144  0.065789 -0.008934 -0.044258 -0.012927  0.052110
# 98787            1145  0.004868  0.017723  0.006210  0.050997  0.065111
# 103879           1214  0.015650  0.050177 -0.057658 -0.000659  0.042336
# 106231           1250 -0.048939 -0.031514  0.020108  0.042079  0.060192
# 106302           1250 -0.048939 -0.031514  0.020108  0.042079  0.060192
# 41297   0.019994  0.044400 -0.069102  0.055650 -0.017280
# 41414  -0.052468  0.049890 -0.067319 -0.034471 -0.013737
# 42931  -0.052092  0.048466  0.004305 -0.010082  0.020421
# 43111  -0.064097  0.061994 -0.068513 -0.048255  0.055522
# 45049  -0.052195  0.032294 -0.057127 -0.050890  0.033067
# 46227   0.058863  0.053507 -0.052933 -0.043914  0.047358
# 49284  -0.020630  0.069775 -0.038852 -0.017935  0.015693
# 53300  -0.061540 -0.022861  0.060186  0.057429  0.037181
# 57090   0.027771 -0.038874 -0.062489  0.016949 -0.022048
# 60046   0.055542  0.052839 -0.058693 -0.039227 -0.007376
# 62299   0.042885  0.039039 -0.061746 -0.046191 -0.043816
# 65458  -0.046044  0.045521 -0.059731  0.026198 -0.013895
# 66709   0.002159  0.033302 -0.057251 -0.002692 -0.048433
# 79513   0.010294  0.056655 -0.062417  0.057350 -0.008448
# 89016  -0.028326  0.046181 -0.010648 -0.019145  0.001768
# 96071   0.022114  0.064894 -0.063652 -0.030319 -0.063220
# 98304   0.065676  0.055150 -0.065391  0.018120  0.018590
# 98305   0.065676  0.055150 -0.065391  0.018120  0.018590
# 98787   0.065503  0.055525 -0.053640  0.044765 -0.011054
# 103879 -0.004871  0.058588 -0.059119  0.037931  0.057954
# 106231 -0.054281  0.058815 -0.056087  0.059353  0.004640
# 106302 -0.054281  0.058815 -0.056087  0.059353  0.004640
# 113171 -0.010762  0.062235 -0.057785 -0.040435  0.033876
# 124164 -0.054960  0.004011 -0.060270  0.041669  0.052099
# 126586 -0.069130  0.014345 -0.060269  0.025569  0.024008
# 126606 -0.059586  0.050256 -0.063669  0.025428 -0.014200
# 128432  0.053048 -0.056888 -0.052431 -0.038210  0.047723
# 128910 -0.056308  0.053280 -0.059787 -0.047226  0.023712
# 133019  0.033819  0.013189 -0.054860 -0.013719  0.043417
# 133484 -0.034805  0.037178 -0.053927 -0.020830 -0.003255
# 133737 -0.020207  0.028496 -0.059801  0.025399  0.006905
# 133769 -0.024328  0.051740 -0.062391 -0.053335 -0.005487
# 141485 -0.029743  0.039832 -0.055303 -0.047326 -0.036044
# 142592  0.058104  0.031324 -0.060260 -0.032830 -0.010110
# 143024 -0.023318  0.063330 -0.068047  0.066011  0.051040
# 143090 -0.023318  0.063330 -0.068047  0.066011  0.051040
# 143954  0.051243  0.050015 -0.060445  0.015754 -0.042359
# 150071  0.088505  0.077831 -0.006141 -0.070577 -0.009020
# 150218  0.086532  0.066997 -0.072254 -0.061693  0.012347
# 152109 -0.058102 -0.020995 -0.044008 -0.008505 -0.022519
#
# [50 rows x 516 columns]

# %%
'''data_embed_rait = data_embed_rait.loc[(data_embed_rait['new_course_id'] != -1) &
                                              (data_embed_rait['new_course_id'] != 1144) &
                                              (data_embed_rait['new_course_id'] != 170) &
                                              (data_embed_rait['new_course_id'] != 1250)]'''
# Out:
# "data_embed_rait = data_embed_rait.loc[(data_embed_rait['new_course_id'] != -1) &\n                                              (data_embed_rait['new_course_id'] != 1144) &\n                                              (data_embed_rait['new_course_id'] != 170) &\n                                              (data_embed_rait['new_course_id'] != 1250)]"

# %%
data_embed_rait.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157938 entries, 0 to 157937
# Columns: 516 entries, course_id to 511
# dtypes: float64(512), int64(3), object(1)
# memory usage: 621.8+ MB

# %%
df_for_user['rating'] = df_for_user.rating.fillna(value = 0)

# %%
df_for_user = df_for_user.drop(['reviewer_id'], axis=1)

# %%
len(df_for_user)
# Out:
# 50

# %%
#df_1 = data_for_user.drop(['rating','average_score'], axis=1)
df_for_user_1 = df_for_user.drop(['course_id'], axis=1)
df_for_user_1.head(3)
# Out:
#       rating  new_course_id         0         1         2         3         4  \
# 3087       5             42 -0.017314 -0.001662 -0.027840 -0.061607  0.042819
# 5387       5             62 -0.008544 -0.022144  0.048564  0.030201  0.011163
# 7190       5             79  0.029129  0.006605 -0.054073 -0.061880  0.057992
#
#              5         6         7  ...       502       503       504  \
# 3087 -0.041902 -0.059788  0.024700  ...  0.041509 -0.056876  0.063003
# 5387 -0.021466 -0.076632 -0.052792  ...  0.014264 -0.069827  0.010156
# 7190  0.051585 -0.061866  0.034730  ... -0.049401 -0.034935  0.066914
#
#            505       506       507       508       509       510       511
# 3087  0.000688 -0.022695  0.037509 -0.023223 -0.057655 -0.010100  0.045322
# 5387  0.009863  0.024559 -0.037045  0.028299 -0.065835 -0.064841  0.011514
# 7190  0.015570 -0.056683  0.030885 -0.006883 -0.049098  0.023755 -0.057493
#
# [3 rows x 514 columns]

# %%
from sklearn.linear_model import LinearRegression # метод наименьших квадратов
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
data_embed_rait['rating']
# Out:
# 0         5
# 1         2
# 2         4
# 3         3
# 4         5
# 5         5
# 6         4
# 7         5
# 8         4
# 9         4
# 10        4
# 11        5
# 12        2
# 13        4
# 14        5
# 15        5
# 16        5
# 17        5
# 18        5
# 19        5
# 20        3
# 21        5
# 22        5
# 23        5
# 24        5
# 25        5
# 26        5
# 27        3
# 28        5
# 29        5
#          ..
# 157908    3
# 157909    5
# 157910    4
# 157911    5
# 157912    5
# 157913    5
# 157914    4
# 157915    4
# 157916    5
# 157917    4
# 157918    5
# 157919    5
# 157920    4
# 157921    5
# 157922    5
# 157923    3
# 157924    4
# 157925    5
# 157926    3
# 157927    5
# 157928    4
# 157929    4
# 157930    4
# 157931    3
# 157932    4
# 157933    5
# 157934    5
# 157935    4
# 157936    4
# 157937    5
# Name: rating, Length: 157938, dtype: int64

# %%
#y = pd.Series(df_for_user['rating']).array
#y

# %%
#разделим обучающую и тестовую выборки
from sklearn.model_selection import train_test_split
X, y = df_for_user_1, df_for_user['rating']
X.head(10)
# Out:
#        rating  new_course_id         0         1         2         3  \
# 3087        5             42 -0.017314 -0.001662 -0.027840 -0.061607
# 5387        5             62 -0.008544 -0.022144  0.048564  0.030201
# 7190        5             79  0.029129  0.006605 -0.054073 -0.061880
# 7390        4             80 -0.027196  0.062703  0.018533 -0.031129
# 8885        5            104  0.007273  0.048132  0.034198 -0.044644
# 11119       4            124  0.030083  0.029936  0.016344  0.029272
columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X.shape[0]
# Out:
# 50

# %%
y.shape[0]
# Out:
# 50

# %%
y.value_counts()
# Out:
# 5    37
# 4     9
# 3     3
# 1     1
# Name: rating, dtype: int64

# %%
X.new_course_id.value_counts()
# Out:
# -1       18
#  1144     2
#  170      2
#  1250     2
#  959      1
#  673      1
#  641      1
#  582      1
#  1145     1
#  520      1
#  1214     1
#  270      1
#  79       1
#  80       1
#  721      1
#  596      1
#  479      1
#  62       1
#  481      1
#  162      1
#  1125     1
#  104      1
#  42       1
#  552      1
#  816      1
#  1072     1
#  751      1
#  799      1
#  124      1
#  512      1
# Name: new_course_id, dtype: int64

# %%
 X_train
# Out:
#         rating  new_course_id         0         1         2         3  \
# 133737       5             -1 -0.031313  0.014460 -0.034069 -0.051523
# 150218       5             -1  0.020991 -0.033611 -0.053113 -0.022784
# 8885         5            104  0.007273  0.048132  0.034198 -0.044644
# 60046        5            721  0.054615 -0.055962  0.056560 -0.059532
# 15389        5            170 -0.040018  0.051751 -0.052735  0.059960
# 143090       5             -1 -0.049081 -0.035454 -0.006034  0.014200
# 98787        4           1145  0.004868  0.017723  0.006210  0.050997
# 65458        5            799 -0.054637  0.060314 -0.023996  0.055392
# 53300        5            641 -0.062531  0.053608 -0.034125  0.061215
# 124164       3             -1  0.044355 -0.010935 -0.059218 -0.050563
# 126606       1             -1  0.067549  0.034317  0.031040  0.061489
# 98305        3           1144  0.065789 -0.008934 -0.044258 -0.012927
# 62299        5            751  0.051021 -0.057186  0.026822  0.064549
# 143954       5             -1 -0.033009 -0.055553 -0.043170 -0.017581
# 142592       5             -1  0.059075 -0.057636 -0.034931  0.059436
# 5387         5             62 -0.008544 -0.022144  0.048564  0.030201
# 128910       5             -1  0.042145 -0.011368 -0.036844  0.043481
# 106302       5           1250 -0.048939 -0.031514  0.020108  0.042079
# 79513        5            959  0.010348  0.054857  0.040544 -0.022212
# 45049        5            552 -0.022204 -0.035900  0.027416  0.069804
# 49284        4            596 -0.064282 -0.014884  0.047591  0.046721
# 21813        4            270  0.010585 -0.033856 -0.017261  0.058840
# 150071       5             -1  0.019197 -0.037425 -0.042237 -0.023644
# 15318        5            170 -0.040018  0.051751 -0.052735  0.059960
# 141485       5             -1  0.030322 -0.040590 -0.060499  0.059089
# 3087         5             42 -0.017314 -0.001662 -0.027840 -0.061607
# 41297        5            479  0.019582 -0.047357 -0.007944  0.078534
# 96071        5           1125 -0.059310 -0.043076  0.044007  0.056553
# 128432       4             -1  0.056295 -0.044152 -0.054807 -0.043207
# 133769       4             -1 -0.045521  0.062886 -0.045772  0.010633
# 113171       5             -1 -0.048551 -0.059052  0.006664 -0.057218
# 143024       3             -1 -0.049081 -0.035454 -0.006034  0.014200
# 89016        4           1072  0.010314 -0.010305 -0.061875  0.014156
# 126586       5             -1 -0.005984 -0.026355 -0.063876 -0.045887
# 66709        5            816  0.028035  0.022869  0.055060  0.057481
# 14792        5            162  0.035675  0.050006 -0.036288 -0.041000
# 43111        5            520 -0.045465  0.006173 -0.054643 -0.032328
# 133019       5             -1  0.049262  0.024942  0.023305  0.004613
# 113171  0.059558  0.006014 -0.055502 -0.010762  0.062235 -0.057785 -0.040435
# 143024  0.060465 -0.063134 -0.068177 -0.023318  0.063330 -0.068047  0.066011
# 89016   0.012342 -0.007071  0.024460 -0.028326  0.046181 -0.010648 -0.019145
# 126586  0.007060 -0.066724  0.060591 -0.069130  0.014345 -0.060269  0.025569
# 66709   0.019423 -0.035636 -0.035862  0.002159  0.033302 -0.057251 -0.002692
# 14792   0.067359 -0.064099  0.039035  0.069284  0.042264 -0.066620 -0.014770
# 43111   0.010134 -0.066956  0.005831 -0.064097  0.061994 -0.068513 -0.048255
# 133019  0.058681 -0.053782 -0.023603  0.033819  0.013189 -0.054860 -0.013719
# 106231  0.058023 -0.038365 -0.045149 -0.054281  0.058815 -0.056087  0.059353
# 98304  -0.035980 -0.048054 -0.064843  0.065676  0.055150 -0.065391  0.018120
#
#              511
# 133737  0.006905
# 150218  0.012347
# 8885   -0.059011
# 60046  -0.007376
# 15389   0.058576
# 143090  0.051040
# 98787  -0.011054
# 65458  -0.013895
# 53300   0.037181
# 124164  0.052099
# 126606 -0.014200
# 98305   0.018590
# 62299  -0.043816
# 143954 -0.042359
# 142592 -0.010110
# 5387    0.011514
# 128910  0.023712
# 106302  0.004640
# 79513  -0.008448
# 45049   0.033067
# 49284   0.015693
# 21813   0.064119
# 150071 -0.009020
# 15318   0.058576
# 141485 -0.036044
# 3087    0.045322
# 41297  -0.017280
# 96071  -0.063220
# 128432  0.047723
# 133769 -0.005487
# 113171  0.033876
# 143024  0.051040
# 89016   0.001768
# 126586  0.024008
# 66709  -0.048433
# 14792  -0.051498
# 43111   0.055522
# 133019  0.043417
# 106231  0.004640
# 98304   0.018590
#
# [40 rows x 514 columns]

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.28986878851923237

# %%
mean_absolute_error(model.predict(X_train), y_train)
# Out:
# 3.83026943495679e-15

# %%
a = y_train.mean()
y_train.mean()
# Out:
# 4.6

# %%
mean_absolute_error(np.ones((len(y_train)))*a, y_train)
# Out:
# 0.6000000000000002

# %%
mean_absolute_error(model.predict(X_test), y_test)
# Out:
# 0.3018211671170669

# %%
models = [LinearRegression, Lasso, Ridge, SVR, RandomForestRegressor]

# %%
for m in models:
    model = m()
    model.fit(X_train, y_train)
    print("{}. r2_train: {:.4f}, r2_test: {:.4f}, mse_train: {:.4f}, mse_test: {:.4f}".format(
        m.__name__,
        model.score(X_train, y_train),
        model.score(X_test, y_test),
        mean_squared_error(model.predict(X_train), y_train),
        mean_squared_error(model.predict(X_test), y_test)
    ))
# Out:
# LinearRegression. r2_train: 1.0000, r2_test: 0.2899, mse_train: 0.0000, mse_test: 0.1491
# Lasso. r2_train: 0.0000, r2_test: -0.0476, mse_train: 0.6900, mse_test: 0.2200
# Ridge. r2_train: 0.9969, r2_test: 0.5785, mse_train: 0.0021, mse_test: 0.0885
# SVR. r2_train: 0.4648, r2_test: 0.1632, mse_train: 0.3693, mse_test: 0.1757
# RandomForestRegressor. r2_train: 0.9779, r2_test: -1.6000, mse_train: 0.0152, mse_test: 0.5460

# %% [markdown]
# # ITEM_TO_ITEM

# %%
from sklearn.neighbors import NearestNeighbors #попарное расстояние между объектами

# %%
#col=col.drop(['course_id'])

# %%
df_for_user = df_for_user.drop(['rating','course_id'], axis=1)

# %%
col = df_for_user.columns

# %%
col
# Out:
# Index(['new_course_id',               0,               1,               2,
#                      3,               4,               5,               6,
#                      7,               8,
#        ...
#                    502,             503,             504,             505,
#                    506,             507,             508,             509,
#                    510,             511],
#       dtype='object', length=513)

# %%
X_unsup = data_courses_embeddings[col]

# %%
sc = StandardScaler()

# %%
# nn = NearestNeighbors(n_neighbors=10, metric='minkowski', p=2) #var. metric='manhettan'

# %%
nn = NearestNeighbors(n_neighbors=10, n_jobs=-1, metric='cosine')

# %%
nn.fit(X_unsup)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=-1, n_neighbors=10, p=2,
#                  radius=1.0)

# %%
df_for_user['new_course_id']
# Out:
# 3087        42
# 5387        62
# 7190        79
# 7390        80
# 8885       104
# 11119      124
# 14792      162
# 15318      170
# 15389      170
# 21813      270
# 41297      479
# 41414      481
# 42931      512
# 43111      520
# 45049      552
# 46227      582
# 49284      596
# 53300      641
# 57090      673
# 60046      721
# 62299      751
# 65458      799
# 66709      816
# 79513      959
# 89016     1072
# 96071     1125
# 98304     1144
# 98305     1144
# 98787     1145
# 103879    1214
# 106231    1250
# 106302    1250
# 113171      -1
# 124164      -1
# 126586      -1
# 126606      -1
# 128432      -1
# 128910      -1
# 133019      -1
# 133484      -1
# 133737      -1
# 133769      -1
# 141485      -1
# 142592      -1
# 143024      -1
# 143090      -1
# 143954      -1
# 150071      -1
# 150218      -1
# 152109      -1
# Name: new_course_id, dtype: int64

# %%
df_for_user.head(3)
# Out:
#       new_course_id         0         1         2         3         4  \
# 3087             42 -0.017314 -0.001662 -0.027840 -0.061607  0.042819
# 5387             62 -0.008544 -0.022144  0.048564  0.030201  0.011163
# 7190             79  0.029129  0.006605 -0.054073 -0.061880  0.057992
#
#              5         6         7         8  ...       502       503  \
# 3087 -0.041902 -0.059788  0.024700  0.044916  ...  0.041509 -0.056876
# 5387 -0.021466 -0.076632 -0.052792  0.034863  ...  0.014264 -0.069827
# 7190  0.051585 -0.061866  0.034730  0.056024  ... -0.049401 -0.034935
#
#            504       505       506       507       508       509       510  \
# 3087  0.063003  0.000688 -0.022695  0.037509 -0.023223 -0.057655 -0.010100
# 5387  0.010156  0.009863  0.024559 -0.037045  0.028299 -0.065835 -0.064841
# 7190  0.066914  0.015570 -0.056683  0.030885 -0.006883 -0.049098  0.023755
#
#            511
# 3087  0.045322
# 5387  0.011514
# 7190 -0.057493
#
# [3 rows x 513 columns]

# %%
courses_eng[courses_eng['new_course_id'] == 80]
# Out:
#     new_course_id                course_id
# 57             80  ancient-marine-reptiles

# %%
nn.kneighbors(df_for_user[df_for_user['new_course_id'] == 80][col]) #возвращает id и расстояние до ближайших курсов
nn
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=-1, n_neighbors=10, p=2,
#                  radius=1.0)

# %%
neighbors = nn.kneighbors(df_for_user[df_for_user['new_course_id'] == 80][col]) 
neighbors
# Out:
# (array([[8.88178420e-16, 6.22656117e-05, 6.24964167e-05, 6.68312342e-05,
#          6.78661378e-05, 6.94024613e-05, 6.95084680e-05, 6.97580132e-05,
#          7.01014341e-05, 7.03582946e-05]]),
#  array([[ 57, 338, 362, 179, 363, 106, 131, 425, 364, 186]], dtype=int64))

# %%
data_courses_embeddings.iloc[neighbors[1][0]]
# Out:
#                       course_id         0         1         2         3  \
# 57      ancient-marine-reptiles -0.027196  0.062703  0.018533 -0.031129
# 338                     dino101 -0.061251 -0.033903  0.034087  0.060027
# 362  early-vertebrate-evolution -0.015435  0.026983 -0.021780  0.044318
# 179             changing-arctic -0.038721 -0.034537 -0.064661  0.015488
# 363                  earth-amnh  0.055042  0.000593 -0.066244 -0.055722
# 106     becoming-a-veterinarian -0.052769  0.017895  0.044355  0.070823
# 131        biological-diversity  0.006164 -0.002703 -0.061931 -0.058711
# 425             evolution-today -0.034808  0.058240  0.012108  0.045887
# 364        earth-climate-change -0.036185 -0.021097 -0.061691  0.026750
# 186                    chickens -0.051215 -0.044830  0.061236  0.060189
#
#             4         5         6         7         8  ...       503  \
# 57   0.020533  0.065593 -0.065088 -0.057435 -0.025556  ...  0.056668
# 338  0.030520  0.006023 -0.070330 -0.036490 -0.008568  ...  0.062748
# 362  0.005881  0.061512 -0.071372 -0.022343  0.028361  ... -0.026440
# 179  0.057139  0.012153 -0.068226  0.054072  0.020669  ... -0.047100
# 363  0.030670  0.005536 -0.066686  0.059240  0.024047  ...  0.032477
# 106  0.003081  0.034146 -0.070907 -0.045489 -0.011852  ... -0.011756
# 131  0.037066 -0.037660 -0.063123  0.020778  0.029938  ... -0.003102
# 425  0.043702 -0.051557 -0.055843  0.047810 -0.043124  ... -0.033729
# 364  0.062992  0.023586 -0.062663 -0.000149  0.016529  ... -0.042928
# 186  0.058194  0.051456 -0.059735 -0.046091 -0.049992  ... -0.046831
#
#           504       505       506       507       508       509       510  \
# 57   0.051834 -0.017262  0.024354 -0.061549  0.044994 -0.055898 -0.046579
# 338  0.042215 -0.061651 -0.038642 -0.052277  0.040712 -0.027639  0.039761
# 362  0.049410 -0.069754  0.032357 -0.052468  0.049890 -0.067319 -0.034471
# 179 -0.045643  0.009640 -0.060391 -0.050679  0.006961 -0.059467 -0.027682
# 363  0.066464 -0.060602 -0.007536 -0.033887  0.046037 -0.064667  0.005629
# 106  0.002633 -0.030082 -0.069238 -0.051280  0.055079 -0.064356 -0.029166
# 131  0.013313 -0.035621 -0.061024 -0.054012  0.052995 -0.062375  0.001895
# 425  0.062667 -0.039766  0.005145  0.053868  0.030185 -0.055958  0.060343
# 364  0.048776  0.037624 -0.036222 -0.045056  0.050780 -0.048987 -0.000134
# 186 -0.042418 -0.033358 -0.024213 -0.060631  0.057451 -0.059085  0.016569
#
#           511  new_course_id
# 57  -0.014056             80
# 338 -0.025011            451
# 362 -0.013737            481
# 179 -0.039804            244
# 363 -0.045169            482
# 106 -0.028320            143
# 131 -0.026525            175
# 425 -0.011592            583
# 364 -0.016552            483
# 186 -0.016709            251
#
# [10 rows x 514 columns]
