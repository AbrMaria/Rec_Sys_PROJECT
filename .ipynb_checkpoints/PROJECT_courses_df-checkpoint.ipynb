# %% [markdown]
# ## Рекомендации курсов на основании оценок и содержания отзывов пользователей

# %% [markdown]
# #### цель построения рекомендаций
#
# - предложить новое (с чего начать изучение темы) - неперсонализированная рекомендация (5 лучших курсов по этой теме) - новичок
# - предложить новое на базе уже изученного (дополнить, углубить и расширить знания в выбранной области) - персонализированная рекомендация (вместе с этим выбирают) - опытный
# - сравнить между собой два/несколько схожих курсов и найти отличия по ключевым словам, оценкам, текстам отзывов - продвинутый

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.neighbors import NearestNeighbors

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
courses_df = pd.read_csv('coursera.csv')

# %% [markdown]
# ## Анализ датасета Coursera course + description

# %%
courses_df.tail(2)
# Out:
#       Unnamed: 0  position course_id  \
# 1772        1772      1773  zhuangzi
# 1773        1773      1774      zika
#
#                                                   title  \
# 1772  莊子─姿勢、意識與感情 (Zhuangzi─Posture, Awareness, and ...
# 1773  In the footsteps of Zika… approaching the unknown
#
#                                 breadcrumbs  \
# 1772  ['Arts and Humanities', 'Philosophy']
# 1773            ['Health', 'Public Health']
#
#                                                   about  \
# 1772  　　他這麼活過他的一生，留下一本書，《莊子》。這本書影響了陶淵明的一生，影響了李太白的一生，...
# 1773  Welcome !\n\nWelcome to this on-demand MOOC “I...
#
#                                             instructors  \
# 1772                                            ['蔡璧名']
# 1773  ['Antoine Flahault', 'Aline Philibert (In Part...
#
#                    language  \
# 1772  Chinese (Traditional)
# 1773                English
#
#                                                 metrics  \
# ...

# %%
courses_df['breadcrumbs'] = courses_df['breadcrumbs'].astype(str)
courses_df['instructors'] = courses_df['instructors'].astype(str)
courses_df['metrics'] = courses_df['metrics'].astype(str)
courses_df['product_glance'] = courses_df['product_glance'].astype(str)
courses_df['skills'] = courses_df['skills'].astype(str)
courses_df['syllabus'] = courses_df['syllabus'].astype(str)
courses_df['recommendations'] = courses_df['recommendations'].astype(str)
courses_df['url'] = courses_df['url'].astype(str)

# %%
#избавимся от лишних столбцов
courses_df=courses_df.drop(['position'], axis=1)

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 16 columns):
# Unnamed: 0         1774 non-null int64
# course_id          1774 non-null object
# title              1774 non-null object
# breadcrumbs        1774 non-null object
# about              1774 non-null object
# instructors        1774 non-null object
# language           1774 non-null object
# metrics            1774 non-null object
# product_glance     1774 non-null object
# average_score      1641 non-null float64
# ratings_count      1504 non-null float64
# reviews_count      1606 non-null float64
# skills             1774 non-null object
# syllabus           1774 non-null object
# recommendations    1774 non-null object
# url                1774 non-null object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 221.8+ KB

# %%
#object в int64
courses_df['course_id'] = courses_df.course_id.astype(str)

# %%
#заменим пропущенные значения на нули
courses_df['average_score'] = courses_df.average_score.fillna(value = 0)
courses_df['reviews_count'] = courses_df.reviews_count.fillna(value = 0)
courses_df['ratings_count'] = courses_df.reviews_count.fillna(value = 0)

# %%
#количество уникальных курсов - проверим на повторы
courses_df.course_id.nunique()
# Out:
# 1774

# %%
#переименуем столбец 'breadcrumbs'
courses_df.rename(columns={'breadcrumbs': 'topics'}, 
                 inplace=True)
courses_df.head(2)
# Out:
#    Unnamed: 0   course_id                                              title  \
# 0           0  2-speed-it  Two Speed IT: How Companies Can Surf the Digit...
# 1           1      20cnwm         20世纪西方音乐 Western Music in the 20th Century
#
#                                      topics  \
# 0       ['Business', 'Business Essentials']
# 1  ['Arts and Humanities', 'Music and Art']
#
#                                                about  \
# 0  Transform or disappear, the Darwinism of IT: I...
# 1  课程所涉不仅涵盖古典音乐如新古典主义、表现主义、民族主义等流派，也对爵士乐、摇滚乐与流行音乐...
#
#                                          instructors              language  \
# 0  ['Antoine Gourévitch', 'Vanessa Lyon', 'Eric B...               English
# 1                           ['毕明辉 Bryan Minghui BI']  Chinese (Simplified)
#
#                                              metrics  \
# 0  ['16,728 already enrolled!', '5,149 recent vie...
# 1                        ['1,795 already enrolled!']
#
# ...

# %%
courses_df.ratings_count = courses_df.ratings_count.astype(int)
courses_df.reviews_count = courses_df.reviews_count.astype(int)

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 16 columns):
# Unnamed: 0         1774 non-null int64
# course_id          1774 non-null object
# title              1774 non-null object
# topics             1774 non-null object
# about              1774 non-null object
# instructors        1774 non-null object
# language           1774 non-null object
# metrics            1774 non-null object
# product_glance     1774 non-null object
# average_score      1774 non-null float64
# ratings_count      1774 non-null int64
# reviews_count      1774 non-null int64
# skills             1774 non-null object
# syllabus           1774 non-null object
# recommendations    1774 non-null object
# url                1774 non-null object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 221.8+ KB

# %%
courses_df.describe()
# Out:
#         Unnamed: 0  average_score  ratings_count  reviews_count
# count  1774.000000    1774.000000    1774.000000    1774.000000
# mean    886.500000       4.275874     113.305524     113.305524
# std     512.254006       1.234137     160.509912     160.509912
# min       0.000000       0.000000       0.000000       0.000000
# 25%     443.250000       4.500000      19.000000      19.000000
# 50%     886.500000       4.600000      53.000000      53.000000
# 75%    1329.750000       4.800000     135.000000     135.000000
# max    1773.000000       5.000000     993.000000     993.000000

# %%
# Распредение признаков
courses_df['language'].value_counts()
# Out:
# English                   1299
# Spanish                    193
# Chinese (Simplified)        83
# Russian                     72
# French                      53
# Portuguese (Brazilian)      30
# Chinese (Traditional)       27
# None                         4
# Turkish                      4
# Arabic                       3
# Hebrew                       3
# Ukrainian                    2
# Swedish                      1
# Name: language, dtype: int64

# %%
#визуализируем самые популярные курсы

plt.rcParams['figure.figsize'] = (10, 8)
plt.style.use('fivethirtyeight')

color = plt.cm.summer(np.linspace(0, 2, 80))
courses_df['language'].value_counts().head(10).plot.bar(color = color)
plt.title('Most Popular Languages', fontsize = 20, fontweight = 30)
plt.xlabel('Languages')
plt.show()

# %%
#Для удобства работы с языковыми библиотеками выделим из общего датасета курсы на английском и на русском языках

# %%
courses_eng = courses_df[courses_df['language'] == 'English']
courses_eng
# Out:
#       Unnamed: 0                                        course_id  \
# 0              0                                       2-speed-it
# 5              5                         3d-printing-applications
# 6              6                           3d-printing-revolution
# 7              7                             3d-printing-software
# 9              9                                  abdomen-anatomy
# 10            10                                     ableton-live
# 11            11                             aboriginal-education
# 12            12                      academic-discussion-english
# 13            13                                academic-literacy
# 14            14                        academic-writing-capstone
# 15            15                                 academicinfoseek
# 16            16                             accounting-analytics
# 17            17                               accounting-finance
# ...

# %%
courses_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1299 entries, 0 to 1773
# Data columns (total 16 columns):
# Unnamed: 0         1299 non-null int64
# course_id          1299 non-null object
# title              1299 non-null object
# topics             1299 non-null object
# about              1299 non-null object
# instructors        1299 non-null object
# language           1299 non-null object
# metrics            1299 non-null object
# product_glance     1299 non-null object
# average_score      1299 non-null float64
# ratings_count      1299 non-null int64
# reviews_count      1299 non-null int64
# skills             1299 non-null object
# syllabus           1299 non-null object
# recommendations    1299 non-null object
# url                1299 non-null object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 172.5+ KB

# %%
courses_ru = courses_df[courses_df['language'] == 'Russian']
courses_ru
# Out:
#       Unnamed: 0                                          course_id  \
# 4              4                                        3d-printing
# 48            48                                  algebra-lineynaya
# 120          120                                        astrofizika
# 174          174                                     bioinformatika
# 176          176                                         biosensory
# 186          186                        bulgakov-master-i-margarita
# 240          240               cennye-bumagi-pravovoe-regulirovanie
# 378          378                         data-analysis-applications
# 380          380                              data-analysis-project
# 505          505                                       ekonometrika
# 506          506                        ekonomicheskaya-sociologiya
# 507          507                       ekonomika-dlya-neekonomistov
# 513          513                                     electrostatica
# ...

# %%
print(len(courses_df.loc[courses_df['language'] == 'Russian']))
# Out:
# 72

# %%
#проверим соответствует ли размар выделенного датасета с курсами на русском языке количеству русскоязычных курсов в исходном датасете
print(len(courses_ru['language']))
# Out:
# 72

# %%
#избавимся от лишних столбцов
courses_ru=courses_ru.drop(['Unnamed: 0'], axis=1)
courses_ru=courses_ru.drop(['url'], axis=1)

# %%
#courses_ru['url'] = courses_ru['url'].astype(str)
#'url'

# %% [markdown]
# ## Анализ датасета Coursera course + users reviews (ru)

# %%
coursera_users_reviews_df = pd.read_csv('coursera_users_reviews_df.csv')

# %%
coursera_users_reviews_df.head()
# Out:
#    Unnamed: 0    course_id reviewer_name  rating  \
# 0           0  3d-printing    Крылов А О       5
# 1           1  3d-printing      Yauhen V       5
# 2           2  3d-printing     Dmitriy O       4
# 3           3  3d-printing  Москинский Г       4
# 4           4  3d-printing        Никита       5
#
#                                          review_text  \
# 0        Замечательный курс, доходчиво рассказывает.
# 1       Курс отличный, жаль не могу бесплатно пройти
# 2  Курс хороший, но слишком базовый. Его бы расши...
# 3  Хороший обзор по 3D печати. Дает базовые знани...
# 4    Введение в 3д печать, было очень познавательно.
#
#                                                  url
# 0  https://www.coursera.org/learn/3d-printing/rev...
# 1  https://www.coursera.org/learn/3d-printing/rev...
# 2  https://www.coursera.org/learn/3d-printing/rev...
# 3  https://www.coursera.org/learn/3d-printing/rev...
# 4  https://www.coursera.org/learn/3d-printing/rev...

# %%
coursera_users_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3836 entries, 0 to 3835
# Data columns (total 6 columns):
# Unnamed: 0       3836 non-null int64
# course_id        3836 non-null object
# reviewer_name    3820 non-null object
# rating           3836 non-null int64
# review_text      3836 non-null object
# url              3836 non-null object
# dtypes: int64(2), object(4)
# memory usage: 179.9+ KB

# %%
#coursera_users_reviews_df['url'] = coursera_users_reviews_df['url'].astype(str)
coursera_users_reviews_df=coursera_users_reviews_df.drop(['url'], axis=1)

# %%
#объединим датафрейм описания русскоязычных курсов с отзывами пользователей 
joined_users_reviews = coursera_users_reviews_df.join(courses_ru.set_index('course_id'), on='course_id')
joined_users_reviews=joined_users_reviews.drop(['Unnamed: 0'], axis=1)

# %%
joined_users_reviews.head()
# Out:
#      course_id reviewer_name  rating  \
# 0  3d-printing    Крылов А О       5
# 1  3d-printing      Yauhen V       5
# 2  3d-printing     Dmitriy O       4
# 3  3d-printing  Москинский Г       4
# 4  3d-printing        Никита       5
#
#                                          review_text  \
# 0        Замечательный курс, доходчиво рассказывает.
# 1       Курс отличный, жаль не могу бесплатно пройти
# 2  Курс хороший, но слишком базовый. Его бы расши...
# 3  Хороший обзор по 3D печати. Дает базовые знани...
# 4    Введение в 3д печать, было очень познавательно.
#
#                           title                                      topics  \
# 0  3D-печать для всех и каждого  ['Computer Science', 'Design and Product']
# 1  3D-печать для всех и каждого  ['Computer Science', 'Design and Product']
# 2  3D-печать для всех и каждого  ['Computer Science', 'Design and Product']
# 3  3D-печать для всех и каждого  ['Computer Science', 'Design and Product']
# ...

# %%
#количество курсов по темам

# %%
c = []
from collections import Counter
for i in joined_users_reviews.topics.str.split(','):
    c = Counter(joined_users_reviews.topics)
print(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-6b6f5fc8ac2a> in <module>()
#       3 for i in joined_users_reviews.topics.str.split(','):
#       4     c = Counter(joined_users_reviews.topics)
# ----> 5 print(c.drop_duplicates())
#
# AttributeError: 'Counter' object has no attribute 'drop_duplicates'

# %%
#inverse document frequency для topics
topics = []
for i in joined_users_reviews.topics.str.split(','):
    for j in i:
        if j not in topics:
            topics.append(j)
            
dict_topics_idf = {i:np.log(len(joined_users_reviews)/topics.count(i)) for i in topics}
dict_topics_idf
# Out:
# {"['Computer Science'": 8.252185436003328,
#  " 'Design and Product']": 8.252185436003328,
#  "['Math and Logic'": 8.252185436003328,
#  " 'Math and Logic']": 8.252185436003328,
#  "['Physical Science and Engineering'": 8.252185436003328,
#  " 'Physics and Astronomy']": 8.252185436003328,
#  "['Health'": 8.252185436003328,
#  " 'Health Informatics']": 8.252185436003328,
#  " 'Research']": 8.252185436003328,
#  "['Language Learning'": 8.252185436003328,
#  " 'Other Languages']": 8.252185436003328,
#  "['Business'": 8.252185436003328,
#  " 'Finance']": 8.252185436003328,
#  "['Data Science'": 8.252185436003328,
#  " 'Data Analysis']": 8.252185436003328,
#  "['Social Sciences'": 8.252185436003328,
#  " 'Economics']": 8.252185436003328,
#  "['Arts and Humanities'": 8.252185436003328,
#  " 'Philosophy']": 8.252185436003328,
#  " 'Nutrition']": 8.252185436003328,
#  " 'Business Essentials']": 8.252185436003328,
#  " 'Mechanical Engineering']": 8.252185436003328,
# ...

# %%
len(dict_topics_idf)
# Out:
# 33

# %%
# посмотрим на гистограмму распределения оценок по всем курсам

plt.rcParams['figure.figsize'] = (10, 5)
joined_users_reviews.rating.hist()

# %%
# средний рейтинг всех курсов по каждому пользователю
reviewer_mean_rating = joined_users_reviews.groupby('reviewer_name')[['rating']].mean().sort_values('reviewer_name')
reviewer_mean_rating.head(10)
# Out:
#                          rating
# reviewer_name
# 080107251209Черчесова М     5.0
# ABDELOUAHAB M               5.0
# Aaliyah                     5.0
# Abdrakhmanov M              5.0
# Abduev S                    5.0
# Abitov D                    5.0
# Ablaikhan A                 3.0
# Ablaikhan G                 5.0
# Abramov A                   5.0
# Adel                        4.0

# %%
#сколько оценок каждого ранга поставил каждый пользователь
joined_users_reviews.groupby('reviewer_name').rating.value_counts().sort_values(ascending=False)
# Out:
# reviewer_name            rating
# Алексей                  5         14
# Deleted A                5         13
# Alexey S                 5         12
# Sergey B                 5         10
# Andrey Y                 5          9
# Petr K                   5          9
# Александр                5          9
# Igor I                   5          8
# Александр К              5          7
# Anna                     5          7
# Alexander S              5          7
# Vladimir Y               5          7
# Sergey                   5          7
# Leonid                   5          7
# Гутиев Б З               5          6
# Дмитрий                  5          6
# Sergey M                 5          6
# Dmitry                   5          6
# Dmitry S                 5          6
# Pavel P                  5          6
# Сергей                   5          6
# Sergei B                 5          6
# Анна                     5          6
# Задойный А               5          6
# ...

# %%
# Выберем только тех пользователей, которые поставили оценку и оставили отзыв больше 5 раз
users_rev_5 = []
joined_users_reviews.groupby('reviewer_name').rating.value_counts().sort_values(ascending=False)
for i in movies_ratings_ml[(movies_ratings_ml.tags.isna()==False)].tags.str.split('|'):
    for j in i :
        tags.append(j)

dict_tags_idf = {i:tags.count(i) for i in tags if tags.count(i)>5 and i!=''}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-c30b60b8c010> in <module>()
#       2 users_rev_5 = []
#       3 joined_users_reviews.groupby('reviewer_name').rating.value_counts().sort_values(ascending=False)
# ----> 4 for i in movies_ratings_ml[(movies_ratings_ml.tags.isna()==False)].tags.str.split('|'):
#       5     for j in i :
#       6         tags.append(j)
#
# NameError: name 'movies_ratings_ml' is not defined

# %% [markdown]
# ### TFIDF для рекоммендаций
# TF (term frequency — частота слова) — отношение числа вхождений некоторого слова к общему числу слов документа. Таким образом, оценивается важность слова $ t_{i} $ в пределах отдельного документа.
#
# $${\displaystyle \mathrm {tf} (t,d)={\frac {n_{t}}{\sum _{k}n_{k}}}},$$
# где ${\displaystyle n_{t}}$ есть число вхождений слова ${\displaystyle t}$ в документ, а в знаменателе — общее число слов в данном документе.
#
# IDF (inverse document frequency — обратная частота документа) — инверсия частоты, с которой некоторое слово встречается в документах коллекции. Основоположником данной концепции является Карен Спарк Джонс. Учёт IDF уменьшает вес широкоупотребительных слов. Для каждого уникального слова в пределах конкретной коллекции документов существует только одно значение IDF.
#
# $${\mathrm {idf} (t,D)=\log {\frac {|D|}{|\{\,d_{i}\in D\mid t\in d_{i}\,\}|}}}$$
# , где
#
# |D| — число документов в коллекции; ${\displaystyle |\{\,d_{i}\in D\mid t\in d_{i}\,\}|}$ — число документов из коллекции D, в которых встречается t (когда ${\displaystyle n_{t}\neq 0}$).
